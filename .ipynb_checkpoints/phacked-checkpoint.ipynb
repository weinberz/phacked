# %%
import numpy as np
import seaborn as sns
from scipy.stats import ttest_ind

# %%
a = np.random.normal(loc=0.1, size=10000)
b = np.random.normal(loc=-0.1, size=10000)
sns.histplot([a,b],kde=True, bins=50, edgecolor=None)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
ttest_ind(a,b)
# Out:
# Ttest_indResult(statistic=14.594647916296076, pvalue=5.363423158719897e-48)

# %%
a = np.random.normal(loc=4, size=10000)
b = np.random.normal(loc=-4, size=10000)
sns.histplot([a,b],kde=True,bins=50,edgecolor=None)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
ttest_ind(a,b)
# Out:
# Ttest_indResult(statistic=568.6418166708442, pvalue=0.0)

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.8/site-packages (4.14.3)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.8/site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.8/site-packages (from plotly) (1.15.0)

# %%
import numpy as np

import plotly.graph_objects as go
from ipywidgets import widgets, Layout

from scipy.stats import ttest_ind

# %%
hist_plot = go.FigureWidget(data=[go.Histogram(), go.Histogram()])

loc_slider = widgets.FloatSlider(value=1, min=0, max=16, description='distance')

n_slider = widgets.IntSlider(value=1000, min=1, max=1e4, description='n_vals')

def update(change):
    dist = loc_slider.value/2
    n = n_slider.value
    a = np.random.normal(loc=dist, size=n)
    b = np.random.normal(loc=-dist, size=n)
    
    with hist_plot.batch_update():
        hist_plot.data[0].x = a
        hist_plot.data[1].x = b
        hist_plot.data[0].opacity = .5
        hist_plot.data[1].opacity = .5
        hist_plot.update_layout(bargap=0,barmode='overlay')

        
        title = 'p = "{:e}'.format(ttest_ind(a,b)[1])
        hist_plot.layout = go.Layout(title=dict(text=title))

loc_slider.observe(update)

n_slider.observe(update)

update(_)

# %%
widgets.VBox([hist_plot, loc_slider, n_slider])
# Out:
# VBox(children=(FigureWidget({
#     'data': [{'opacity': 0.5,
#               'type': 'histogram',
#               '…
